# %%
import pandas as pd

# Create a pandas series with an index
tf = pd.Series([386, 924, 942, 567, 362, 472, 655, 366], index=['915.2', '915.4', '915.6', '915.8', '916.0', '916.2', '916.4', '916.6'])
print(tf)
tf.name = 'count'
tf.index.name = 'freq'
tf = tf.to_frame()

print(tf.info())
# Out:
# 915.2    386
# 915.4    924
# 915.6    942
# 915.8    567
# 916.0    362
# 916.2    472
# 916.4    655
# 916.6    366
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 915.2 to 916.6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   8 non-null      int64
# dtypes: int64(1)
# memory usage: 128.0+ bytes
# None
